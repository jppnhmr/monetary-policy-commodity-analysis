# %%
import src.database as db
import src.analysis as anls

pir_datas = anls.get_pir_datas()
idx_datas = anls.get_idx_datas()

# %% [markdown]
# # Policy Interest Rates vs Indicies
# The following graph gives an overview of the collected data.
#
# Quaterly indicies (all commodities) were forward sampled to fill empty data points.
# Other indicies were collected as monthly data points.
# Interest rates (US, UK) use monthly mean values.
#
# # Rolling Correlations
# 36-month rolling correlation of US Rates and Indicies.
#
# A 3 year window shows the reponses to new ecenomic trends, while filtering out the usual noise inherent in this data.

# %%
anls.analysis()
